# %% [markdown]
# <h3>DATAFRAME</h3>

# %%
import pandas as pd

# %%
path="C:/Users/Data Science/Documents/GitHub/Python/17.Python-Pandas/files/"

# %%
nba = pd.read_csv(path + "nba.csv")

# %% [markdown]
# ***Introduction to `Attributes`***

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.ndim
# Out:
# 2

# %%
nba.size
# Out:
# 4122

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %% [markdown]
# ***The `.head(), .tail(), .info(), .get_dtype_counts(), .sum()` Methods***

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %%
rev=pd.read_csv(path + "revenue.csv",index_col="Date")
print(len(rev))
rev.head()
# Out:
# 10
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933
# 1/4/16       730          904    885
# 1/5/16       114           71    253

# %%
rev.sum(axis = "columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev.sum(axis = "index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis=0)
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis=1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# ***Select One Column from a `DataFrame`***

# %%
nba = pd.read_csv(path + "nba.csv")

# %%
nba["Team"].head()
# Out:
# 0    Boston Celtics
# 1    Boston Celtics
# 2    Boston Celtics
# 3    Boston Celtics
# 4    Boston Celtics
# Name: Team, dtype: object

# %%
nba.Team.head()
# Out:
# 0    Boston Celtics
# 1    Boston Celtics
# 2    Boston Celtics
# 3    Boston Celtics
# 4    Boston Celtics
# Name: Team, dtype: object

# %% [markdown]
# ***Select Two or More Columns from A `DataFrame`***

# %%
nba = pd.read_csv(path + "nba.csv")

# %%
nba[["Team", "Name"]].head()
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland
# 3  Boston Celtics    R.J. Hunter
# 4  Boston Celtics  Jonas Jerebko

# %%
nba[["Salary", "Team", "Name"]].tail()
# Out:
#         Salary       Team          Name
# 453  2433333.0  Utah Jazz  Shelvin Mack
# 454   900000.0  Utah Jazz     Raul Neto
# 455  2900000.0  Utah Jazz  Tibor Pleiss
# 456   947276.0  Utah Jazz   Jeff Withey
# 457        NaN        NaN           NaN

# %%
select = ["Salary", "Team", "Name"]
nba[select].head()
# Out:
#       Salary            Team           Name
# 0  7730337.0  Boston Celtics  Avery Bradley
# 1  6796117.0  Boston Celtics    Jae Crowder
# 2        NaN  Boston Celtics   John Holland
# 3  1148640.0  Boston Celtics    R.J. Hunter
# 4  5000000.0  Boston Celtics  Jonas Jerebko

# %% [markdown]
# ***`Add New Column` to `DataFrame`***

# %%
nba = pd.read_csv(path + "nba.csv")

# %%
nba["Sport"] = "Basketball"
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba["League"] = "National Basketball Association"
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport                           League
# 0              Texas  7730337.0  Basketball  National Basketball Association
# 1          Marquette  6796117.0  Basketball  National Basketball Association
# 2  Boston University        NaN  Basketball  National Basketball Association
# 3      Georgia State  1148640.0  Basketball  National Basketball Association
# 4                NaN  5000000.0  Basketball  National Basketball Association

# %%
nba = pd.read_csv(path + "nba.csv")

# %%
nba.insert(3, column = "Sport", value = "Basketball")
nba.head()
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %%
nba.insert(7, column = "League", value = "National Basketball Association")

# %%
nba.head()
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#                             League  Weight            College     Salary
# 0  National Basketball Association   180.0              Texas  7730337.0
# 1  National Basketball Association   235.0          Marquette  6796117.0
# 2  National Basketball Association   205.0  Boston University        NaN
# 3  National Basketball Association   185.0      Georgia State  1148640.0
# 4  National Basketball Association   231.0                NaN  5000000.0

# %% [markdown]
# ***Broadcasting Operations using `.add(),.sub(),.mul(),.div()`***

# %%
nba = pd.read_csv(path + "nba.csv")

# %%
nba["Age"].add(5)
nba["Age"] + 5

nba["Salary"].sub(5000000)
nba["Salary"] - 5000000

nba["Weight"].mul(0.453592)
nba["Weight in Kilograms"] = nba["Weight"] * 0.453592

nba["Salary"].div(1000000)
nba["Salary in Millions"] = nba["Salary"] / 1000000

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in Kilograms  Salary in Millions
# 0              Texas  7730337.0            81.646560            7.730337
# 1          Marquette  6796117.0           106.594120            6.796117
# 2  Boston University        NaN            92.986360                 NaN
# 3      Georgia State  1148640.0            83.914520            1.148640
# 4                NaN  5000000.0           104.779752            5.000000

# %% [markdown]
# ***The `.value_counts()` Method***

# %%
nba = pd.read_csv(path + "nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Milwaukee Bucks           16
# New York Knicks           16
# Atlanta Hawks             15
# Chicago Bulls             15
# Boston Celtics            15
# Portland Trail Blazers    15
# Philadelphia 76ers        15
# Oklahoma City Thunder     15
# Miami Heat                15
# Los Angeles Clippers      15
# Sacramento Kings          15
# Washington Wizards        15
# Charlotte Hornets         15
# Toronto Raptors           15
# Golden State Warriors     15
# Houston Rockets           15
# Indiana Pacers            15
# Denver Nuggets            15
# Dallas Mavericks          15
# Brooklyn Nets             15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Cleveland Cavaliers       15
# San Antonio Spurs         15
# Utah Jazz                 15
# Detroit Pistons           15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
nba["Position"].value_counts().head()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba["Weight"].value_counts().tail()
# Out:
# 278.0    1
# 227.0    1
# 239.0    1
# 289.0    1
# 307.0    1
# Name: Weight, dtype: int64

# %%
nba["Salary"].value_counts().head()
# Out:
# 947276.0     31
# 845059.0     18
# 525093.0     13
# 981348.0      6
# 1100602.0     5
# Name: Salary, dtype: int64

# %% [markdown]
# ***The `.dropna()` Method***

# %%
nba = pd.read_csv(path + "nba.csv")

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna(axis=0,how = "all").tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.dropna(axis=0,how="any",subset = ["Salary", "College"]).tail()
# Out:
#               Name       Team  Number Position   Age Height  Weight   College  \
# 449    Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0      Duke
# 451  Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0    Dayton
# 452     Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453   Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 456    Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 449  1348440.0
# 451   981348.0
# 452  2239800.0
# 453  2433333.0
# 456   947276.0

# %%
nba = pd.read_csv(path + "nba.csv")

# %%
nba.size
# Out:
# 4122

# %%
nba.dropna(inplace = True)

# %%
nba.size
# Out:
# 3276

# %% [markdown]
# ***The `.fillna()` Method***

# %%
nba = pd.read_csv(path + "nba.csv")

# %%
nba.fillna(0)
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
#
# 17     6-4   200.0     North Carolina   1500000.0
# 18     6-7   220.0            Arizona   1335480.0
# 19     6-3   200.0       Georgia Tech   6300000.0
# 20     6-7   208.0                  0   1599840.0
# 21     6-4   219.0         Cincinnati    134215.0
# 22    5-11   175.0         Miami (FL)   1500000.0
# 23     7-0   275.0           Stanford  19689000.0
# 24    6-11   200.0           Syracuse   1140240.0
# 25    6-10   220.0        Saint Louis    947276.0
# 26    6-10   237.0             Kansas    981348.0
# 27    6-10   248.0         Georgetown    947276.0
# 28     6-3   205.0          Texas A&M    947276.0
# 29     6-8   221.0       Georgia Tech  11235955.0
# ..     ...     ...                ...         ...
# 428    6-9   215.0        Wake Forest   8042895.0
# 429    6-5   206.0         Notre Dame    625093.0
# 430    6-6   210.0         California    947276.0
# 431   6-10   240.0     North Carolina   6980802.0
# 432    6-9   215.0         St. John's   2894059.0
# 433    6-5   215.0               Duke   6000000.0
# 434    7-0   265.0   Central Michigan   5016000.0
# 435    7-1   245.0           Illinois   3075880.0
# 436    6-3   195.0        Weber State   4236287.0
# 437    6-4   200.0             Lehigh   2525160.0
# 438    6-7   185.0     Westchester CC    525093.0
# 439   6-11   235.0               Duke   1415520.0
# 440    6-1   173.0             Dayton   2854940.0
# 441    6-9   240.0            Indiana   2637720.0
# 442    6-8   228.0            Clemson   4775000.0
# 443    6-1   191.0           Michigan   2658240.0
# 444    6-6   214.0           Colorado   9463484.0
# 445    6-6   190.0                  0   3777720.0
# 446   6-10   265.0       Georgia Tech  12000000.0
# 447    7-1   245.0                  0   1175880.0
# 448    6-8   226.0             Butler  15409570.0
# 449    6-8   206.0               Duke   1348440.0
# 450    6-8   226.0                  0   2050000.0
# 451    6-6   206.0             Dayton    981348.0
# 452   6-10   234.0           Kentucky   2239800.0
# 453    6-3   203.0             Butler   2433333.0
# 454    6-1   179.0                  0    900000.0
# 455    7-3   256.0                  0   2900000.0
# 456    7-0   231.0             Kansas    947276.0
# 457      0     0.0                  0         0.0
#
# [458 rows x 9 columns]

# %%
nba["Salary"].fillna(0, inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["College"].fillna("No College", inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %% [markdown]
# ***The `.astype()` Method***

# %%
nba = pd.read_csv(path + "nba.csv").dropna(how = "all")
nba["Salary"].fillna(0, inplace = True)
nba["College"].fillna("None", inplace = True)
nba.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         0.0
# 3      Georgia State   1148640.0
# 4               None   5000000.0
# 5               None  12000000.0

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      458 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba["Salary"] = nba["Salary"].astype("int")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Number"] = nba["Number"].astype("int")
nba["Age"] = nba["Age"].astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Age"].astype("float")
# Out:
# 0      25.0
# 1      25.0
# 2      27.0
# 3      22.0
# 4      29.0
# 5      29.0
# 6      21.0
# 7      25.0
# 8      22.0
# 9      22.0
# 10     24.0
# 11     27.0
# 12     27.0
# 13     20.0
# 14     26.0
# 15     27.0
# 16     24.0
# 17     28.0
# 18     21.0
# 19     32.0
# 20     22.0
# 21     26.0
# 22     23.0
# 23     28.0
# 24     21.0
# 25     26.0
# 26     25.0
# 27     26.0
# 28     28.0
# 29     27.0
#        ...
# 427    20.0
# 428    25.0
# 429    23.0
# 430    24.0
# 431    27.0
# 432    23.0
# 433    28.0
# 434    34.0
# 435    24.0
# 436    25.0
# 437    24.0
# 438    23.0
# 439    26.0
# 440    30.0
# 441    20.0
# 442    28.0
# 443    23.0
# 444    24.0
# 445    20.0
# 446    24.0
# 447    23.0
# 448    26.0
# 449    23.0
# 450    28.0
# 451    26.0
# 452    20.0
# 453    26.0
# 454    24.0
# 455    26.0
# 456    26.0
# Name: Age, dtype: float64

# %%
nba["Position"].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C', nan], dtype=object)

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba["Team"] = nba["Team"].astype("category")

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4               None  5000000

# %% [markdown]
# ***The `.sort_values()` Method***

# %%
nba = pd.read_csv(path + "nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values("Name", ascending = False)

nba.sort_values("Age", ascending = False)

nba.sort_values("Salary", ascending = False, inplace = True)

nba.head(3)
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
#
#      Weight   College      Salary
# 109   212.0       NaN  25000000.0
# 169   250.0       NaN  22970500.0
# 33    240.0  Syracuse  22875000.0

# %%
nba.sort_values("Salary", ascending = False, na_position = "first").tail()
# Out:
#                        Name                  Team  Number Position   Age  \
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#     Height  Weight           College    Salary
# 175    6-5   179.0         Tennessee  111196.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 32     6-7   205.0               NaN   30888.0

# %%
nba.sort_values(["Team", "Name"], ascending = [True, False], inplace = True)
nba.head(3)
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 322    Walter Tavares  Atlanta Hawks    22.0        C  24.0    7-3   260.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 321    Tiago Splitter  Atlanta Hawks    11.0        C  31.0   6-11   245.0
#
#       College     Salary
# 322       NaN  1000000.0
# 310  Michigan  1304520.0
# 321       NaN  9756250.0

# %% [markdown]
# ***The `.sort_index()` Method***

# %%
nba = pd.read_csv(path + "nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values(["Number", "Salary", "Name"], inplace = True)
nba.tail(3)
# Out:
#                Name             Team  Number Position   Age Height  Weight  \
# 68   Lucas Nogueira  Toronto Raptors    92.0        C  23.0    7-0   220.0
# 1       Jae Crowder   Boston Celtics    99.0       SF  25.0    6-6   235.0
# 457             NaN              NaN     NaN      NaN   NaN    NaN     NaN
#
#        College     Salary
# 68         NaN  1842000.0
# 1    Marquette  6796117.0
# 457        NaN        NaN

# %%
nba.sort_index(ascending = False, inplace = True)

# %%
nba.head(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
#
#         Salary
# 457        NaN
# 456   947276.0
# 455  2900000.0

# %% [markdown]
# ***The `.rank()` Method***

# %%
nba = pd.read_csv(path + "nba.csv").dropna(how = "all")
nba["Salary"] = nba["Salary"].fillna(0).astype("int")

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#          College     Salary  Salary Rank
# 0          Texas  7730337.0           74
# 1      Marquette  6796117.0           83
# 3  Georgia State  1148640.0          254

# %%
nba.sort_values(by = "Salary", ascending = False)
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James     Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 339              Chris Bosh              Miami Heat     1.0       PF  32.0
# 100              Chris Paul    Los Angeles Clippers     3.0       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0
# 164            Derrick Rose           Chicago Bulls     1.0       PG  27.0
# 349             Dwyane Wade              Miami Heat     3.0       SG  34.0
# 174              Kevin Love     Cleveland Cavaliers     0.0       PF  27.0
# 98           DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0
# 23              Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 294       LaMarcus Aldridge       San Antonio Spurs    12.0       PF  30.0
# 265              Marc Gasol       Memphis Grizzlies    33.0        C  31.0
# 96            Blake Griffin    Los Angeles Clippers    32.0       PF  27.0
# 315            Paul Millsap           Atlanta Hawks     4.0       PF  31.0
# 199             Paul George          Indiana Pacers    13.0       SF  26.0
# 426       Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0
# 168            Kyrie Irving     Cleveland Cavaliers     2.0       PG  24.0
# 233         Wesley Matthews        Dallas Mavericks    23.0       SG  29.0
# 301           Kawhi Leonard       San Antonio Spurs     2.0       SF  24.0
# 418             Enes Kanter   Oklahoma City Thunder    11.0        C  24.0
# 153            Jimmy Butler           Chicago Bulls    21.0       SG  26.0
# 220             Greg Monroe         Milwaukee Bucks    15.0        C  26.0
# 96    6-10   251.0               Oklahoma  18907726           15
# 315    6-8   246.0         Louisiana Tech  18671659           16
# 199    6-9   220.0           Fresno State  17120106           17
# 426    6-3   200.0                   UCLA  16744218           18
# 168    6-3   193.0                   Duke  16407501           19
# 233    6-5   220.0              Marquette  16407500           22
# 301    6-7   230.0        San Diego State  16407500           22
# 418   6-11   245.0               Kentucky  16407500           22
# 153    6-7   220.0              Marquette  16407500           22
# 220   6-11   265.0             Georgetown  16407500           22
# 189    6-9   235.0              Tennessee  16000000           25
# 382    6-4   195.0               Kentucky  15851950           26
# 143   6-11   270.0               Kentucky  15851950           26
# 249    6-5   220.0          Arizona State  15756438           28
# 111    7-2   270.0             Georgetown  15592217           29
# 288    6-4   215.0                Indiana  15514031           30
# ..     ...     ...                    ...       ...          ...
# 304    6-3   200.0                   Utah    250750          428
# 73    6-11   250.0                  Rider    245177          429
# 420   6-10   250.0               Kentucky    222888          430
# 203   5-11   195.0         North Carolina    211744          431
# 123    6-7   209.0                Arizona    206192          432
# 248    6-3   200.0             Charleston    200600          434
# 381    6-4   205.0                    LSU    200600          434
# 303    6-7   199.0       Western Carolina    200600          434
# 326    6-3   189.0             California    189455          436
# 282    6-6   203.0             Iowa State    169883          437
# 45     6-6   205.0             Washington    167406          438
# 21     6-4   219.0             Cincinnati    134215          439
# 92     6-9   250.0          Arizona State    111444          440
# 184    6-5   189.0   North Carolina State    111444          440
# 175    6-5   179.0              Tennessee    111196          442
# 135    6-8   260.0       UC Santa Barbara     83397          443
# 130   5-11   175.0               Missouri     55722          444
# 291    6-5   220.0       UC Santa Barbara     55722          444
# 32     6-7   205.0                    NaN     30888          446
# 350    6-2   165.0  Virginia Commonwealth         0          452
# 46     6-9   254.0                   Duke         0          452
# 2      6-5   205.0      Boston University         0          452
# 171    6-6   225.0                   Duke         0          452
# 397    6-7   210.0                    NaN         0          452
# 269    6-3   190.0                Detroit         0          452
# 353    6-9   205.0                    NaN         0          452
# 264    6-2   180.0                   UCLA         0          452
# 409   6-10   250.0           Fresno State         0          452
# 273   6-10   270.0                    USC         0          452
# 270    6-3   180.0           Rhode Island         0          452
#
# [457 rows x 10 columns]

# %% [markdown]
# ***`Filter A DataFrame` Based `On A Condition`***

# %%
df = pd.read_csv(path + "employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-10-07 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-10-07 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-10-07 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df["Gender"]=="Male"
df[df["Gender"]=="Male"]
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 970    False
# 971     True
# 972    False
# 973     True
# 974     True
# 975    False
# 976    False
# 977    False
# 978     True
# 979     True
# 980    False
# 981     True
# 982    False
# 983     True
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992     True
# 993    False
# 994     True
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
mask=df["Gender"]=="Male"
df[mask]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2019-06-03 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2019-06-03 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2019-06-03 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2019-06-03 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 
# 556     Arthur   Male 2014-12-16 2019-06-03 16:56:00   66819    6.639
# 571   Jonathan   Male 1995-04-06 2019-06-03 22:38:00   56993   18.623
# 581     Ernest   Male 1990-01-28 2019-06-03 00:08:00   81919   15.118
# 696     Samuel   Male 2012-05-25 2019-06-03 16:40:00   85550   11.593
# 722     Joshua   Male 1997-06-27 2019-06-03 15:23:00   95003    5.197
# 798   Lawrence   Male 1984-10-01 2019-06-03 14:06:00  102589   17.952
# 860    Phillip   Male 1984-10-07 2019-06-03 11:05:00   36837   14.660
# 867       Earl   Male 2013-06-15 2019-06-03 03:00:00   48046    7.737
# 899     Walter   Male 1992-05-21 2019-06-03 00:39:00  144701   16.323
# 947        NaN   Male 2012-07-30 2019-06-03 15:07:00  107351    5.329
# 994     George   Male 2013-06-21 2019-06-03 17:47:00   98874    4.479
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# 26                True  Marketing
# 74               False  Marketing
# 77                True  Marketing
# 101               True  Marketing
# 104              False  Marketing
# 112              False  Marketing
# 119              False  Marketing
# 150              False  Marketing
# 187              False  Marketing
# 204               True  Marketing
# 216              False  Marketing
# 252               True  Marketing
# 274               True  Marketing
# 293              False  Marketing
# 309              False  Marketing
# 327               True  Marketing
# 353               True  Marketing
# 403              False  Marketing
# 413               True  Marketing
# 452               True  Marketing
# 454               True  Marketing
# 461              False  Marketing
# 464              False  Marketing
# 484              False  Marketing
# 496               True  Marketing
# 503               True  Marketing
# 544               True  Marketing
# 550               True  Marketing
# 556               True  Marketing
# 571              False  Marketing
# 581              False  Marketing
# 696               True  Marketing
# 722               True  Marketing
# 798               True  Marketing
# 860              False  Marketing
# 867              False  Marketing
# 899               True  Marketing
# 947               True  Marketing
# 994               True  Marketing

# %%
mask1 = df["Senior Management"]
mask2 = df["Start Date"] < "1990-01-01"
df[mask1 | mask2]

# %%
mask1 = df["First Name"] == "Robert"
mask2 = df["Team"] == "Client Services"
mask3 = df["Start Date"] > "2016-06-01"
df[(mask1 & mask2) | mask3]

# %% [markdown]
# ***The `.isin()` Method***

# %%
mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"
df[mask1 | mask2 | mask3]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5         Dennis    Male 1987-04-18 2019-06-03 01:35:00  115163   10.125
# 6           Ruby  Female 1987-08-17 2019-06-03 16:20:00   65476   10.012
# 11         Julie  Female 1997-10-26 2019-06-03 15:19:00  102508   12.637
# 13          Gary    Male 2008-01-27 2019-06-03 23:40:00  109831    5.831
# 15       Lillian  Female 2016-06-05 2019-06-03 06:09:00   59414    1.256
# 17         Shawn    Male 1986-12-07 2019-06-03 19:45:00  111737    6.414
# 19         Donna  Female 2010-07-22 2019-06-03 03:48:00   81014    1.894
# 20          Lois     NaN 1995-04-22 2019-06-03 19:18:00   64714    4.934
# 27         Scott     NaN 1991-07-11 2019-06-03 18:58:00  122367    5.218
# 29      Benjamin    Male 2005-01-26 2019-06-03 22:06:00   79529    7.008
12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2019-10-06 18:24:00  129949   10.169
#
#      Senior Management       Team
# 0                 True  Marketing
# 5                False      Legal
# 6                 True    Product
# 11                True      Legal
# 13               False      Sales
# 15               False    Product
# 17               False    Product
# 19               False    Product
# 20                True      Legal
# 21               False  Marketing
# 26                True  Marketing
# 27               False      Legal
# 29                True      Legal
# 31               False    Product
# 35               False      Sales
# 42               False      Legal
# 43                True  Marketing
# 44                True    Product
# 45                True      Sales
# 49               False      Sales
# 51                True      Sales
# 55                True    Product
# 62                True  Marketing
# 71                True      Sales
# 72               False    Product
# 73                True      Sales
# 74               False  Marketing
# 77                True  Marketing
# 78                True      Sales
# 79               False    Product
# ..                 ...        ...
# 910               True      Legal
# 913              False  Marketing
# 917              False    Product
# 921               True      Sales
# 925               True      Sales
# 929               True      Legal
# 930               True  Marketing
# 942               True  Marketing
# 947               True  Marketing
# 953              False    Product
# 955              False      Legal
# 957               True      Sales
# 961              False      Legal
# 962              False    Product
# 963               True      Sales
# 964               True      Sales
# 970               True    Product
# 972               True      Sales
# 975              False      Sales
# 976               True      Legal
# 977              False    Product
# 979               True    Product
# 981              False      Legal
# 985              False      Legal
# 986              False  Marketing
# 989              False      Legal
# 991               True  Marketing
# 994               True  Marketing
# 997              False    Product
# 999               True      Sales
#
# [375 rows x 8 columns]

# %% [markdown]
# ***The `.isnull()` and `.notnull()` Methods***

# %%
mask = df["Team"].isnull()
df[mask]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2019-10-06 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2019-10-06 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2019-10-06 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2019-10-06 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2019-10-06 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2019-10-06 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2019-10-06 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2019-10-06 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2019-10-06 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2019-10-06 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2019-10-06 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2019-10-06 06:06:00   66067   10.957
# 382          NaN  Female 1996-04-18 2019-10-06 15:57:00  107024   12.182
# 434        Joyce  Female 1995-02-07 2019-10-06 07:38:00   50701   14.227
# 438        Jason    Male 1998-11-20 2019-10-06 14:54:00   69244    6.220
# 445        Chris    Male 2006-12-12 2019-10-06 01:57:00   71642    1.496
# 479      Richard    Male 1997-07-04 2019-10-06 11:47:00   47647   18.787
# 512        Wanda  Female 1993-04-06 2019-10-06 03:11:00   78883   19.695
# 513        Jimmy    Male 2013-11-19 2019-10-06 19:29:00   63549   19.624
# 520        Peter    Male 2003-02-22 2019-10-06 09:09:00   56580    8.411
# 567          NaN  Female 1980-04-01 2019-10-06 20:04:00   48141   12.605
# 573     Kimberly  Female 1981-12-30 2019-10-06 04:51:00   81800    5.435
# 580        Harry    Male 1985-01-27 2019-10-06 20:18:00   65482   18.089
# 626          NaN  Female 1997-04-13 2019-10-06 08:03:00  131755    2.930
# 634         Carl    Male 1987-03-30 2019-10-06 17:59:00   75598   19.289
# 635        Randy    Male 2000-09-27 2019-10-06 03:04:00   89831   13.047
# 647       Donald    Male 1988-04-06 2019-10-06 10:00:00  122920    5.320
# 669       Joseph     NaN 1982-03-28 2019-10-06 13:05:00   86564   11.879
# 684        Alice  Female 2016-01-21 2019-10-06 17:07:00  117787   10.485
# 706         Todd    Male 1993-07-04 2019-10-06 18:53:00  128175   18.473
# 726       Daniel    Male 2016-02-29 2019-10-06 04:04:00   77287   13.000
# 753      Antonio    Male 1999-06-06 2019-10-06 22:54:00   41928    5.478
# 774          NaN  Female 2000-06-18 2019-10-06 07:36:00  106428   10.867
# 781     Lawrence    Male 1995-07-03 2019-10-06 22:55:00   46378    9.127
# 794       Nicole  Female 2004-03-01 2019-10-06 17:17:00   44021   10.286
# 826          NaN     NaN 1988-08-01 2019-10-06 01:35:00   87103    5.665
# 850      Charles    Male 1997-09-03 2019-10-06 10:04:00  148291    6.002
# 851        Bobby    Male 1996-08-19 2019-10-06 01:16:00  147842   16.158
# 853      Mildred  Female 2007-04-06 2019-10-06 22:06:00  139284   11.390
# 855      Phillip     NaN 2003-10-20 2019-10-06 11:09:00   89700    2.277
# 864         Ryan    Male 2012-11-16 2019-10-06 13:47:00   57292    6.010
# 912          Joe    Male 1998-12-08 2019-10-06 10:28:00  126120    1.020
# 951          NaN  Female 2010-09-14 2019-10-06 05:19:00  143638    9.662
#
#      Senior Management Team
# 1                 True  NaN
# 10                True  NaN
# 23                True  NaN
# 32                True  NaN
# 91               False  NaN
# 109              False  NaN
# 139               True  NaN
# 199               True  NaN
# 258              False  NaN
# 290               True  NaN
# 314              False  NaN
# 367               True  NaN
# 382               True  NaN
# 434               True  NaN
# 438               True  NaN
# 445              False  NaN
# 479               True  NaN
# 512              False  NaN
# 513              False  NaN
# 520               True  NaN
# 567               True  NaN
# 573               True  NaN
# 580              False  NaN
# 626               True  NaN
# 634              False  NaN
# 635               True  NaN
# 647              False  NaN
# 669               True  NaN
# 684              False  NaN
# 706               True  NaN
# 726               True  NaN
# 753               True  NaN
# 774               True  NaN
# 781              False  NaN
# 794              False  NaN
# 826               True  NaN
# 850              False  NaN
# 851               True  NaN
# 853               True  NaN
# 855               True  NaN
# 864              False  NaN
# 912              False  NaN
# 951               True  NaN

# %%
mask = df["Team"].notnull()
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-10-06 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2019-10-06 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2019-10-06 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2019-10-06 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2019-10-06 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 
20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2019-10-06 07:04:00   82871   17.999
# 987     Gloria  Female 2014-12-08 2019-10-06 05:08:00  136709   10.331
# 988      Alice  Female 2004-10-05 2019-10-06 09:34:00   47638   11.209
# 989     Justin     NaN 1991-02-10 2019-10-06 16:58:00   38344    3.794
# 990      Robin  Female 1987-07-24 2019-10-06 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2019-10-06 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2019-10-06 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2019-10-06 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2019-10-06 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2019-10-06 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2019-10-06 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2019-10-06 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2019-10-06 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2019-10-06 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# 6                 True               Product
# 7                 True               Finance
# 8                 True           Engineering
# 9                 True  Business Development
# 11                True                 Legal
# 12                True       Human Resources
# 13               False                 Sales
# 14                True               Finance
# 15               False               Product
# 16               False       Human Resources
# 17               False               Product
# 18               False       Client Services
# 19               False               Product
# 20                True                 Legal
# 21               False             Marketing
# 22                True       Client Services
# 24               False       Client Services
# 25                True       Client Services
# 26                True             Marketing
# 27               False                 Legal
# 28                True       Client Services
# 29                True                 Legal
# 30                True           Engineering
# 31               False               Product
# 33               False  Business Development
# ..                 ...                   ...
# 970               True               Product
# 971               True  Business Development
# 972               True                 Sales
# 973              False  Business Development
# 974               True       Client Services
# 975              False                 Sales
# 976               True                 Legal
# 977              False               Product
# 978              False       Human Resources
# 979               True               Product
# 980               True           Engineering
# 981              False                 Legal
# 982               True       Human Resources
# 983              False           Engineering
# 984              False           Engineering
# 985              False                 Legal
# 986              False             Marketing
# 987               True               Finance
# 988              False       Human Resources
# 989              False                 Legal
# 990               True       Client Services
# 991               True             Marketing
# 992               True               Finance
# 993               True           Engineering
# 994               True             Marketing
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [957 rows x 8 columns]

# %% [markdown]
# ***The `.between()` Method***

# %%
df[df["Salary"].between(60000, 70000)]

# %%
df[df["Bonus %"].between(2.0, 5.0)]

# %%
df[df["Start Date"].between("1991-01-01", "1992-01-01")]

# %%
df[df["Last Login Time"].between("08:30AM", "12:00PM")]

# %% [markdown]
# ***The `.duplicated()` Method***

# %%
df = pd.read_csv(path + "employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace = True)
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2019-10-06 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2019-10-06 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2019-10-06 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2019-10-06 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2019-10-06 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2019-10-06 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2019-10-06 11:59:00   71276    5.027
# 538       Adam    Male 2010-10-08 2019-10-06 21:53:00   45181    3.491
# 300       Alan    Male 1988-06-26 2019-10-06 03:54:00  111786    3.592
# 53        Alan     NaN 2014-03-03 2019-10-06 13:28:00   40341   17.578
# 610       Alan    Male 2012-02-17 2019-10-06 00:26:00   41453   10.084
# 372     Albert    Male 1997-02-01 2019-10-06 16:20:00   67827   19.717
# 458     Albert    Male 2007-09-30 2019-10-06 17:34:00  102626   15.843
# 477     Albert    Male 2008-08-14 2019-10-06 17:43:00  137840    9.705
# 680     Albert    Male 1992-06-17 2019-10-06 03:25:00   86818   14.301
# 999     Albert    Male 2012-05-15 2019-10-06 18:24:00  129949   10.169
# 959     Albert    Male 1992-09-19 2019-10-06 02:35:00   45094    5.850
15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2019-10-06 05:19:00  143638    9.662
#
#      Senior Management                  Team
# 101               True             Marketing
# 327               True             Marketing
# 440               True       Client Services
# 937              False       Client Services
# 137              False          Distribution
# 141               True               Product
# 302               True       Human Resources
# 538              False       Human Resources
# 300               True           Engineering
# 53                True               Finance
# 610              False               Product
# 372               True           Engineering
# 458              False               Finance
# 477              False  Business Development
# 680               True           Engineering
# 999               True                 Sales
# 959               True  Business Development
# 988              False       Human Resources
# 970               True               Product
# 765               True               Finance
# 425               True               Finance
# 905               True               Finance
# 684              False                   NaN
# 935              False           Engineering
# 693              False                 Sales
# 639               True       Client Services
# 642              False               Finance
# 578               True               Product
# 553              False           Engineering
# 542               True          Distribution
# ..                 ...                   ...
# 567               True                   NaN
# 574               True       Client Services
# 599               True       Human Resources
# 607               True                 Sales
# 608               True           Engineering
# 626               True                   NaN
# 628               True          Distribution
# 674               True       Human Resources
# 685               True               Finance
# 687               True          Distribution
# 697               True          Distribution
# 709               True       Human Resources
# 733               True  Business Development
# 734               True       Human Resources
# 773               True               Finance
# 774               True                   NaN
# 782               True       Client Services
# 783               True               Product
# 785               True             Marketing
# 812               True               Product
# 821               True          Distribution
# 823               True           Engineering
# 826               True                   NaN
# 877               True       Client Services
# 890               True               Finance
# 902               True          Distribution
# 925               True                 Sales
# 946               True          Distribution
# 947               True             Marketing
# 951               True                   NaN
#
# [1000 rows x 8 columns]

# %%
~df["First Name"].duplicated(keep = False)
# Out:
# 101    False
# 327    False
# 440    False
# 937    False
# 137    False
# 141    False
# 302    False
# 538    False
# 300    False
# 53     False
# 610    False
# 372    False
# 458    False
# 477    False
# 680    False
# 999    False
# 959    False
# 988    False
# 970    False
# 765    False
# 425    False
# 905    False
# 684    False
# 935    False
# 693    False
# 639    False
# 642    False
# 578    False
# 553    False
# 542    False
#        ...
# 567    False
# 574    False
# 599    False
# 607    False
# 608    False
# 626    False
# 628    False
# 674    False
# 685    False
# 687    False
# 697    False
# 709    False
# 733    False
# 734    False
# 773    False
# 774    False
# 782    False
# 783    False
# 785    False
# 812    False
# 821    False
# 823    False
# 826    False
# 877    False
# 890    False
# 902    False
# 925    False
# 946    False
# 947    False
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
# Keep first rww  if "First Name" is duplicated
mask = ~df["First Name"].duplicated(keep ='first')
df[mask]
# Keep last row if "First Name" is duplicated
mask = ~df["First Name"].duplicated(keep ='last')
df[mask]
# Keep only those rows in which "First Name" is not duplicated (or "First Name" is only once)
mask = ~df["First Name"].duplicated(keep =False)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2019-10-06 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2019-10-06 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2019-10-06 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2019-10-06 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2019-10-06 09:34:00   47638   11.209
# 639     Amanda     NaN 1991-08-11 2019-10-06 14:15:00   46665   19.391
# 879        Amy  Female 2009-05-20 2019-10-06 06:26:00   75415   19.132
# 430     Andrea  Female 2010-10-01 2019-10-06 11:54:00   79123   19.422
# 564     Andrew    Male 1985-03-29 2019-10-06 18:57:00   43414    7.563
# 8       Angela  Female 2005-11-22 2019-10-06 06:29:00   95570   18.523
# 664    Timothy    Male 2010-10-06 2019-10-06 22:49:00   49473   12.463
# 113       Tina  Female 2009-06-12 2019-10-06 07:16:00  114767    3.711
# 609       Todd    Male 2010-02-16 2019-10-06 11:29:00  103405   15.910
# 422     Victor    Male 2005-09-24 2019-10-06 12:04:00  123144   16.261
# 294   Virginia  Female 1999-10-20 2019-10-06 06:23:00   46905   19.154
# 288     Walter     NaN 1999-12-21 2019-10-06 22:33:00   66757   18.099
# 433      Wanda  Female 2008-07-20 2019-10-06 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2019-10-06 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2019-10-06 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2019-10-06 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2019-10-06 10:43:00   45906   11.598
#
#      Senior Management                  Team
# 101               True             Marketing
# 137              False          Distribution
# 300               True           Engineering
# 372               True           Engineering
# 988              False       Human Resources
# 639               True       Client Services
# 879              False       Client Services
# 430              False          Distribution
# 564               True       Client Services
# 8                 True           Engineering
# 509              False  Business Development
# 645              False             Marketing
# 262               True           Engineering
# 87                True                 Sales
# 886              False                 Sales
# 129               True  Business Development
# 556               True             Marketing
# 138               True           Engineering
# 735               True  Business Development
# 757              False               Product
# 894               True             Marketing
# 956              False           Engineering
# 838              False          Distribution
# 776              False       Human Resources
# 79               False               Product
# 892              False                 Sales
# 872              False  Business Development
# 688               True                 Legal
# 604               True           Engineering
# 282              False       Client Services
# ..                 ...                   ...
# 696               True             Marketing
# 589               True       Human Resources
# 882               True          Distribution
# 417              False       Human Resources
# 452               True             Marketing
# 501              False          Distribution
# 489               True       Client Services
# 804              False          Distribution
# 130               True       Human Resources
# 475               True           Engineering
# 756               True          Distribution
# 525               True       Human Resources
# 743               True       Human Resources
# 975              False                 Sales
# 291               True       Client Services
# 613              False               Finance
# 762               True          Distribution
# 795               True       Human Resources
# 967              False           Engineering
# 664              False                 Legal
# 113               True           Engineering
# 609              False                 Sales
# 422               True               Product
# 294              False          Distribution
# 288              False          Distribution
# 433               True                 Legal
# 177               True          Distribution
# 820               True       Human Resources
# 450              False                 Legal
# 7                 True               Finance
#
# [201 rows x 8 columns]

# %% [markdown]
# ***The `.drop_duplicates()` Method***

# %%
df = pd.read_csv(path + "employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace = True)
df.head(3)

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())

# %%
df.drop_duplicates(subset = ["First Name"], keep = False)

# %%
df.drop_duplicates(subset = ["First Name", "Team"], inplace = True)

# %%
df.head(2)

# %%
len(df)

# %% [markdown]
# ***The `.unique()` and `.nunique()` Methods***

# %%
df = pd.read_csv(path + "employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-10-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-10-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-10-06 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-10-06 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-10-06 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
print(df["Gender"].unique())
df["Team"].unique()
# Out:
# [Male, Female, NaN]
# Categories (2, object): [Male, Female]
# [Marketing, NaN, Finance, Client Services, Legal, ..., Engineering, Business Development, Human Resources, Sales, Distribution]
# Length: 11
# Categories (10, object): [Marketing, Finance, Client Services, Legal, ..., Business Development, Human Resources, Sales, Distribution]

# %%
len(df["Team"].unique())
# Out:
# 11

# %%
df["Team"].nunique(dropna = False)

# %% [markdown]
# ***The `.set_index()` and `.reset_index()` Methods***

# %%
bond = pd.read_csv(path + "jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.set_index("Film", inplace = True)
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.reset_index(drop = False, inplace = True)
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.set_index("Film", inplace = True)
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.reset_index(inplace = True)
bond.set_index("Year", inplace = True)
bond.head()
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965            Thunderball  Sean Connery  Terence Young       848.1    41.9
# 1967          Casino Royale   David Niven     Ken Hughes       315.0    85.0
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2
# 1965                4.7
# 1967                NaN

# %% [markdown]
# ***`Retrieve Row(s)` by `Index Label` with `.loc[]`***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc["GoldenEye"]
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
bond.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc["Diamonds Are Forever" : "Moonraker"]
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
# Live and Let Die       1973     Roger Moore     Guy Hamilton       460.3
# Moonraker              1979     Roger Moore    Lewis Gilbert       535.0
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6
# GoldenEye                76.9                5.1
# Goldfinger               18.6                3.2
# Licence to Kill          56.7                7.9
# Live and Let Die         30.8                NaN
# Moonraker                91.5                NaN

# %%
bond.loc[: "On Her Majesty's Secret Service"]
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# Moonraker                        1979     Roger Moore    Lewis Gilbert
# Never Say Never Again            1983    Sean Connery   Irvin Kershner
# Octopussy                        1983     Roger Moore        John Glen
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.loc[["Octopussy", "Moonraker"]]
# Out:
#            Year        Actor       Director  Box Office  Budget  \
# Film
# Octopussy  1983  Roger Moore      John Glen       373.8    53.9
# Moonraker  1979  Roger Moore  Lewis Gilbert       535.0    91.5
#
#            Bond Actor Salary
# Film
# Octopussy                7.8
# Moonraker                NaN

# %%
bond.loc[["For Your Eyes Only", "Live and Let Die", "Gold Bond"]]

# %%
"Gold Bond" in bond.index

# %% [markdown]
# ***`Retrieve Row(s)` by `Index Position` with `iloc[]`***

# %%
bond = pd.read_csv(path + "jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.loc[15]
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond.iloc[15]
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond.iloc[[15, 20]]
# Out:
#                        Film  Year           Actor       Director  Box Office  \
# 15         A View to a Kill  1985     Roger Moore      John Glen       275.2
# 20  The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
#
#     Budget  Bond Actor Salary
# 15    54.5                9.1
# 20   158.3               13.5

# %%
bond.iloc[:4]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7

# %%
bond.iloc[4:8]
# Out:
#                               Film  Year           Actor       Director  \
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6
# 7       442.5    34.7                5.8

# %%
bond.iloc[20:]
# Out:
#                        Film  Year           Actor         Director  \
# 20  The World Is Not Enough  1999  Pierce Brosnan    Michael Apted
# 21          Die Another Day  2002  Pierce Brosnan     Lee Tamahori
# 22            Casino Royale  2006    Daniel Craig  Martin Campbell
# 23        Quantum of Solace  2008    Daniel Craig     Marc Forster
# 24                  Skyfall  2012    Daniel Craig       Sam Mendes
# 25                  Spectre  2015    Daniel Craig       Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3                NaN

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.iloc[[5, 10, 15, 20]]
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# Licence to Kill                  1989  Timothy Dalton      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Man with the Golden Gun      1974     Roger Moore   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Man with the Golden Gun           334.0    27.7                NaN

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Moonraker", ["Actor", "Budget", "Year"]]
# Out:
# Actor     Roger Moore
# Budget           91.5
# Year             1979
# Name: Moonraker, dtype: object

# %%
bond.iloc[14, [5, 3, 2]]
# Out:
# Bond Actor Salary          7.8
# Box Office               373.8
# Director             John Glen
# Name: Octopussy, dtype: object

# %% [markdown]
# ***`Set New Values` for a `Specific Cell or Row`***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Dr. No"]
# Out:
# Year                          1962
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                           7
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
bond.loc["Dr. No", "Actor"] = "Sir Sean Connery"

# %%
bond.loc["Dr. No", ["Box Office", "Budget", "Bond Actor Salary"]] = [448800000, 7000000, 600000]

# %%
bond.loc["Dr. No", "Budget"]
# Out:
# 7000000.0

# %%
bond.loc["Dr. No"]
# Out:
# Year                             1962
# Actor                Sir Sean Connery
# Director                Terence Young
# Box Office                  4.488e+08
# Budget                          7e+06
# Bond Actor Salary              600000
# Name: Dr. No, dtype: object

# %% [markdown]
# ***`Set Multiple Values` in `DataFrame`***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
mask = bond["Actor"] == "Sean Connery"

# %%
bond.loc[mask, "Actor"] = "Sir Sean Connery"

# %%
mask = bond["Actor"] == "Sir Sean Connery"

# %%
bond.loc[mask]
# Out:
#                        Year             Actor        Director  Box Office  \
# Film
# Diamonds Are Forever   1971  Sir Sean Connery    Guy Hamilton       442.5
# Dr. No                 1962  Sir Sean Connery   Terence Young       448.8
# From Russia with Love  1963  Sir Sean Connery   Terence Young       543.8
# Goldfinger             1964  Sir Sean Connery    Guy Hamilton       820.4
# Never Say Never Again  1983  Sir Sean Connery  Irvin Kershner       380.0
# Thunderball            1965  Sir Sean Connery   Terence Young       848.1
# You Only Live Twice    1967  Sir Sean Connery   Lewis Gilbert       514.2
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# Never Say Never Again    86.0                NaN
# Thunderball              41.9                4.7
# You Only Live Twice      59.9                4.4

# %%
bond[mask]
# Out:
#                        Year             Actor        Director  Box Office  \
# Film
# Diamonds Are Forever   1971  Sir Sean Connery    Guy Hamilton       442.5
# Dr. No                 1962  Sir Sean Connery   Terence Young       448.8
# From Russia with Love  1963  Sir Sean Connery   Terence Young       543.8
# Goldfinger             1964  Sir Sean Connery    Guy Hamilton       820.4
# Never Say Never Again  1983  Sir Sean Connery  Irvin Kershner       380.0
# Thunderball            1965  Sir Sean Connery   Terence Young       848.1
# You Only Live Twice    1967  Sir Sean Connery   Lewis Gilbert       514.2
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# Never Say Never Again    86.0                NaN
# Thunderball              41.9                4.7
# You Only Live Twice      59.9                4.4

# %% [markdown]
# ***The `.rename()` Method***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(columns = {"Year" : "Release Date", "Box Office" : "Revenue"}, inplace = True)

# %%
bond.head()
# Out:
#                       Release Date           Actor         Director  Revenue  \
# Film
# A View to a Kill              1985     Roger Moore        John Glen    275.2
# Casino Royale                 2006    Daniel Craig  Martin Campbell    581.5
# Casino Royale                 1967     David Niven       Ken Hughes    315.0
# Diamonds Are Forever          1971    Sean Connery     Guy Hamilton    442.5
# Die Another Day               2002  Pierce Brosnan     Lee Tamahori    465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(index = {"Dr. No" : "Doctor No", 
                     "GoldenEye" : "Golden Eye",
                     "The World Is Not Enough" : "Best Bond Movie Ever"}, 
                     inplace = True)

# %%
bond.loc["Best Bond Movie Ever"]
# Out:
# Release Date                   1999
# Actor                Pierce Brosnan
# Director              Michael Apted
# Revenue                       439.5
# Budget                        158.3
# Bond Actor Salary              13.5
# Name: Best Bond Movie Ever, dtype: object

# %%
bond.head()
# Out:
#                       Release Date           Actor         Director  Revenue  \
# Film
# A View to a Kill              1985     Roger Moore        John Glen    275.2
# Casino Royale                 2006    Daniel Craig  Martin Campbell    581.5
# Casino Royale                 1967     David Niven       Ken Hughes    315.0
# Diamonds Are Forever          1971    Sean Connery     Guy Hamilton    442.5
# Die Another Day               2002  Pierce Brosnan     Lee Tamahori    465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.columns = ["Year of Release", "Actor", "Director", "Gross", "Cost", "Salary"]

# %%
bond.head()
# Out:
#                       Year of Release           Actor         Director  Gross  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen  275.2
# Casino Royale                    2006    Daniel Craig  Martin Campbell  581.5
# Casino Royale                    1967     David Niven       Ken Hughes  315.0
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton  442.5
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori  465.4
#
#                        Cost  Salary
# Film
# A View to a Kill       54.5     9.1
# Casino Royale         145.3     3.3
# Casino Royale          85.0     NaN
# Diamonds Are Forever   34.7     5.8
# Die Another Day       154.2    17.9

# %% [markdown]
# ***The `.drop()` Method***

# %%
import pandas as pd
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.drop(labels = ["Box Office", "Bond Actor Salary", "Actor"], axis = "columns", inplace = True)

# %%
bond.head()
# Out:
#                       Year         Director  Budget
# Film
# A View to a Kill      1985        John Glen    54.5
# Casino Royale         2006  Martin Campbell   145.3
# Casino Royale         1967       Ken Hughes    85.0
# Diamonds Are Forever  1971     Guy Hamilton    34.7
# Die Another Day       2002     Lee Tamahori   154.2

# %%
actor = bond.pop("Budget")

# %%
actor.head()
# Out:
# Film
# A View to a Kill         54.5
# Casino Royale           145.3
# Casino Royale            85.0
# Diamonds Are Forever     34.7
# Die Another Day         154.2
# Name: Budget, dtype: float64

# %%
del bond["Director"]

# %%
del bond["Year"]

# %% [markdown]
# ***The `.sample()` Method***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.sample(n = 3, axis = "columns").head()
# Out:
#                       Year           Actor  Budget
# Film
# A View to a Kill      1985     Roger Moore    54.5
# Casino Royale         2006    Daniel Craig   145.3
# Casino Royale         1967     David Niven    85.0
# Diamonds Are Forever  1971    Sean Connery    34.7
# Die Another Day       2002  Pierce Brosnan   154.2

# %%
bond.sample(n = 5, axis = "index")
# Out:
#                          Year           Actor       Director  Box Office  \
# Film
# Skyfall                  2012    Daniel Craig     Sam Mendes       943.5
# You Only Live Twice      1967    Sean Connery  Lewis Gilbert       514.2
# Thunderball              1965    Sean Connery  Terence Young       848.1
# The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
# From Russia with Love    1963    Sean Connery  Terence Young       543.8
#
#                          Budget  Bond Actor Salary
# Film
# Skyfall                   170.2               14.5
# You Only Live Twice        59.9                4.4
# Thunderball                41.9                4.7
# The World Is Not Enough   158.3               13.5
# From Russia with Love      12.6                1.6

# %% [markdown]
# ***The `.nsmallest()` and `.nlargest()` Methods***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.sort_values("Box Office", ascending = False).head()
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Skyfall        2012  Daniel Craig       Sam Mendes       943.5   170.2
# Thunderball    1965  Sean Connery    Terence Young       848.1    41.9
# Goldfinger     1964  Sean Connery     Guy Hamilton       820.4    18.6
# Spectre        2015  Daniel Craig       Sam Mendes       726.7   206.3
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Skyfall                     14.5
# Thunderball                  4.7
# Goldfinger                   3.2
# Spectre                      NaN
# Casino Royale                3.3

# %%
bond.nlargest(n = 3, columns = "Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nsmallest(n = 2, columns = "Box Office")
# Out:
#                   Year           Actor   Director  Box Office  Budget  \
# Film
# Licence to Kill   1989  Timothy Dalton  John Glen       250.9    56.7
# A View to a Kill  1985     Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# Licence to Kill                 7.9
# A View to a Kill                9.1

# %%
bond["Box Office"].nlargest(3)
# Out:
# Film
# Skyfall        943.5
# Thunderball    848.1
# Goldfinger     820.4
# Name: Box Office, dtype: float64

# %%
bond["Box Office"].nsmallest(2)
# Out:
# Film
# Licence to Kill     250.9
# A View to a Kill    275.2
# Name: Box Office, dtype: float64

# %% [markdown]
# ***The `.where()` Method***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
mask1 = bond["Actor"] == "Sean Connery"
bond[mask1]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.where(mask1)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# Never Say Never Again            1983.0  Sean Connery  Irvin Kershner
# Octopussy                           NaN           NaN             NaN
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Quantum of Solace                   NaN           NaN             NaN
# Skyfall                             NaN           NaN             NaN
# Spectre                             NaN           NaN             NaN
# The Living Daylights                NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# The World Is Not Enough             NaN           NaN             NaN
# Thunderball                      1965.0  Sean Connery   Terence Young
# Tomorrow Never Dies                 NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                        NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                         NaN     NaN                NaN
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                      NaN     NaN                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                               NaN     NaN                NaN
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                         NaN     NaN                NaN
# Live and Let Die                        NaN     NaN                NaN
# Moonraker                               NaN     NaN                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                               NaN     NaN                NaN
# On Her Majesty's Secret Service         NaN     NaN                NaN
# Quantum of Solace                       NaN     NaN                NaN
# Skyfall                                 NaN     NaN                NaN
# Spectre                                 NaN     NaN                NaN
# The Living Daylights                    NaN     NaN                NaN
# The Man with the Golden Gun             NaN     NaN                NaN
# The Spy Who Loved Me                    NaN     NaN                NaN
# The World Is Not Enough                 NaN     NaN                NaN
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                     NaN     NaN                NaN
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.where(bond["Box Office"] > 800)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# Moonraker                           NaN           NaN            NaN
# Never Say Never Again               NaN           NaN            NaN
# Octopussy                           NaN           NaN            NaN
# On Her Majesty's Secret Service     NaN           NaN            NaN
# Quantum of Solace                   NaN           NaN            NaN
# Skyfall                          2012.0  Daniel Craig     Sam Mendes
# Spectre                             NaN           NaN            NaN
# The Living Daylights                NaN           NaN            NaN
# The Man with the Golden Gun         NaN           NaN            NaN
# The Spy Who Loved Me                NaN           NaN            NaN
# The World Is Not Enough             NaN           NaN            NaN
# Thunderball                      1965.0  Sean Connery  Terence Young
# Tomorrow Never Dies                 NaN           NaN            NaN
# You Only Live Twice                 NaN           NaN            NaN
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                        NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Diamonds Are Forever                    NaN     NaN                NaN
# Die Another Day                         NaN     NaN                NaN
# Dr. No                                  NaN     NaN                NaN
# For Your Eyes Only                      NaN     NaN                NaN
# From Russia with Love                   NaN     NaN                NaN
# GoldenEye                               NaN     NaN                NaN
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                         NaN     NaN                NaN
# Live and Let Die                        NaN     NaN                NaN
# Moonraker                               NaN     NaN                NaN
# Never Say Never Again                   NaN     NaN                NaN
# Octopussy                               NaN     NaN                NaN
# On Her Majesty's Secret Service         NaN     NaN                NaN
# Quantum of Solace                       NaN     NaN                NaN
# Skyfall                               943.5   170.2               14.5
# Spectre                                 NaN     NaN                NaN
# The Living Daylights                    NaN     NaN                NaN
# The Man with the Golden Gun             NaN     NaN                NaN
# The Spy Who Loved Me                    NaN     NaN                NaN
# The World Is Not Enough                 NaN     NaN                NaN
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                     NaN     NaN                NaN
# You Only Live Twice                     NaN     NaN                NaN

# %%
mask2 = bond["Box Office"] > 800

# %%
bond.where(mask & mask2)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# Moonraker                           NaN           NaN            NaN
# Never Say Never Again               NaN           NaN            NaN
# Octopussy                           NaN           NaN            NaN
# On Her Majesty's Secret Service     NaN           NaN            NaN
# Quantum of Solace                   NaN           NaN            NaN
# Skyfall                             NaN           NaN            NaN
# Spectre                             NaN           NaN            NaN
# The Living Daylights                NaN           NaN            NaN
# The Man with the Golden Gun         NaN           NaN            NaN
# The Spy Who Loved Me                NaN           NaN            NaN
# The World Is Not Enough             NaN           NaN            NaN
# Thunderball                      1965.0  Sean Connery  Terence Young
# Tomorrow Never Dies                 NaN           NaN            NaN
# You Only Live Twice                 NaN           NaN            NaN
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                        NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Diamonds Are Forever                    NaN     NaN                NaN
# Die Another Day                         NaN     NaN                NaN
# Dr. No                                  NaN     NaN                NaN
# For Your Eyes Only                      NaN     NaN                NaN
# From Russia with Love                   NaN     NaN                NaN
# GoldenEye                               NaN     NaN                NaN
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                         NaN     NaN                NaN
# Live and Let Die                        NaN     NaN                NaN
# Moonraker                               NaN     NaN                NaN
# Never Say Never Again                   NaN     NaN                NaN
# Octopussy                               NaN     NaN                NaN
# On Her Majesty's Secret Service         NaN     NaN                NaN
# Quantum of Solace                       NaN     NaN                NaN
# Skyfall                                 NaN     NaN                NaN
# Spectre                                 NaN     NaN                NaN
# The Living Daylights                    NaN     NaN                NaN
# The Man with the Golden Gun             NaN     NaN                NaN
# The Spy Who Loved Me                    NaN     NaN                NaN
# The World Is Not Enough                 NaN     NaN                NaN
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                     NaN     NaN                NaN
# You Only Live Twice                     NaN     NaN                NaN

# %% [markdown]
# ***The `.query()` Method***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.columns = [column_name.replace(" ", "_") for column_name in bond.columns]
bond.head()
# Out:
#                       Year           Actor         Director  Box_Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond_Actor_Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.query("Director == 'Terence Young'")
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
bond.query("Actor != 'Roger Moore'")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Never Say Never Again                 380.0    86.0                NaN
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.query("Box_Office > 600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor == 'Roger Moore' and Director == 'John Glen'")
# Out:
#                     Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
#
#                     Bond_Actor_Salary
# Film
# A View to a Kill                  9.1
# For Your Eyes Only                NaN
# Octopussy                         7.8

# %%
bond.query("Actor in ['Timothy Dalton', 'George Lazenby']")
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Living Daylights             1987  Timothy Dalton      John Glen
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Living Daylights                  313.5    68.8                5.2

# %%
bond.query("Actor not in ['Sean Connery', 'Roger Moore']")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Licence to Kill                  1989  Timothy Dalton           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Die Another Day                       465.4   154.2               17.9
# GoldenEye                             518.5    76.9                5.1
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The World Is Not Enough               439.5   158.3               13.5
# Tomorrow Never Dies                   463.2   133.9               10.0

# %% [markdown]
# ***The `.apply()` Method on `Single Columns`***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + " MILLIONS!"

# %%
columns = ["Box Office", "Budget", "Bond Actor Salary"]
for col in columns:
    bond[col] = bond[col].apply(convert_to_string_and_add_millions)

# %%
bond.head()
# Out:
#                       Year           Actor         Director       Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen  275.2 MILLIONS!
# Casino Royale         2006    Daniel Craig  Martin Campbell  581.5 MILLIONS!
# Casino Royale         1967     David Niven       Ken Hughes  315.0 MILLIONS!
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton  442.5 MILLIONS!
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori  465.4 MILLIONS!
#
#                                Budget Bond Actor Salary
# Film
# A View to a Kill       54.5 MILLIONS!     9.1 MILLIONS!
# Casino Royale         145.3 MILLIONS!     3.3 MILLIONS!
# Casino Royale          85.0 MILLIONS!     nan MILLIONS!
# Diamonds Are Forever   34.7 MILLIONS!     5.8 MILLIONS!
# Die Another Day       154.2 MILLIONS!    17.9 MILLIONS!

# %% [markdown]
# ***The `.apply()` Method with `Row Values`***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
def good_movie(row):
    
    actor = row[1]
    budget = row[4]
    
    if actor == "Pierce Brosnan":
        return "The best"
    elif actor == "Roger Moore" and budget > 40:
        return "Enjoyable"
    else:
        return "I have no clue"
    
bond.apply(good_movie, axis = "columns")
# Out:
# Film
# A View to a Kill                        Enjoyable
# Casino Royale                      I have no clue
# Casino Royale                      I have no clue
# Diamonds Are Forever               I have no clue
# Die Another Day                          The best
# Dr. No                             I have no clue
# For Your Eyes Only                      Enjoyable
# From Russia with Love              I have no clue
# GoldenEye                                The best
# Goldfinger                         I have no clue
# Licence to Kill                    I have no clue
# Live and Let Die                   I have no clue
# Moonraker                               Enjoyable
# Never Say Never Again              I have no clue
# Octopussy                               Enjoyable
# On Her Majesty's Secret Service    I have no clue
# Quantum of Solace                  I have no clue
# Skyfall                            I have no clue
# Spectre                            I have no clue
# The Living Daylights               I have no clue
# The Man with the Golden Gun        I have no clue
# The Spy Who Loved Me                    Enjoyable
# The World Is Not Enough                  The best
# Thunderball                        I have no clue
# Tomorrow Never Dies                      The best
# You Only Live Twice                I have no clue
# dtype: object

# %% [markdown]
# ***The `.copy()` Method***

# %%
bond = pd.read_csv(path + "jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
directors = bond["Director"]
directors.head()
# Out:
# Film
# A View to a Kill              John Glen
# Casino Royale           Martin Campbell
# Casino Royale                Ken Hughes
# Diamonds Are Forever       Guy Hamilton
# Die Another Day            Lee Tamahori
# Name: Director, dtype: object

# %%
directors["A View to a Kill"] = "Mister John Glen"
# Out:
# C:\Users\Data Science\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
directors.head()
# Out:
# Film
# A View to a Kill        Mister John Glen
# Casino Royale            Martin Campbell
# Casino Royale                 Ken Hughes
# Diamonds Are Forever        Guy Hamilton
# Die Another Day             Lee Tamahori
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor          Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore  Mister John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig   Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven        Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond["Director"].copy()
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
directors["A View to a Kill"] = "Mister John Glen"

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor          Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore  Mister John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig   Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven        Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN
